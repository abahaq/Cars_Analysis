# %%
from sklearn.impute import SimpleImputer

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/user/Desktop/data science/cars.xlsx')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv   cty   hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p
# 3           audi      a4    2.0  2008    4    auto(av)   f  21.0  30.0  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...   ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f  19.0  28.0  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f  21.0  29.0  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f  16.0  26.0  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f  18.0  26.0  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f  17.0  26.0  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# ...

# %%
df.isnull().sum()
# Out:
# manufacturer    0
# model           0
# displ           5
# year            0
# cyl             0
# trans           0
# drv             0
# cty             4
# hwy             6
# fl              0
# class           0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
imputer=imputer.fit(df[['hwy']])
df['hwy'] = imputer.transform(df[['hwy']]).ravel()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df['displ']=df['displ'].fillna(method='backfill')

# %%
df['cty']=df['cty'].fillna(method='backfill')

# %%
df.corr()
# Out:
#           displ      year       cyl       cty       hwy
# displ  1.000000  0.142325  0.932760 -0.766434 -0.759956
# year   0.142325  1.000000  0.122245 -0.025750 -0.014512
# cyl    0.932760  0.122245  1.000000 -0.778331 -0.760983
# cty   -0.766434 -0.025750 -0.778331  1.000000  0.931851
# hwy   -0.759956 -0.014512 -0.760983  0.931851  1.000000

# %% [markdown]
# cyl and displ is the most with 0.932

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['hwy'],df['cty'],label="some dots",color = 'red')
plt.legend()

# %% [markdown]
# good corellated and near to 1.

# %%
sns.pairplot(df,hue='drv',palette='coolwarm')

# %% [markdown]
# hwy and cty is the most, hwy and displ is the least.

# %%
sns.countplot(x='class',data=df)

# %%
sns.barplot(x='drv',y='cyl',data=df)

# %% [markdown]
# rear wheel drive cars is the most

# %%
sns.boxplot(x="class", y="displ", data=df,palette='rainbow')

# %%
sns.violinplot(x="class", y="displ", data=df,palette='rainbow')
